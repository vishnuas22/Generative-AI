# %% [markdown]
# Google Gemini Model integration

# %%
import os

print(bool(os.getenv("GEMINI_API_KEY")))
# Out:
# True

# %%
from langchain.chat_models import init_chat_model

from langchain_google_genai import ChatGoogleGenerativeAI

gemini = ChatGoogleGenerativeAI(model="gemini-2.5-flash-lite")

response = gemini.invoke("Talk me about black holes?")

response.content
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# File ~/Agentic AI/.venv/lib/python3.13/site-packages/langchain_google_genai/chat_models.py:4177, in ChatGoogleGenerativeAI._generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    4176 try:
# -> 4177     response: GenerateContentResponse = self.client.models.generate_content(
#    4178         **request,
#    4179     )
#    4180 except ClientError as e:
#
# File ~/Agentic AI/.venv/lib/python3.13/site-packages/google/genai/models.py:6270, in Models.generate_content(self, model, contents, config)
#    6269 i += 1
# -> 6270 response = self._generate_content(
#    6271     model=model, contents=contents, config=parsed_config_to_call
#    6272 )
#    6274 if not function_map:
#
# ...
